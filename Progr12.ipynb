# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Progr12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to check eligible for vote or not

age = int(input("Enter age: "))

result = "Eligible" if age >= 18 else "Not Eligible"
print(result)
# Out:
# Enter age: 45
# Eligible
