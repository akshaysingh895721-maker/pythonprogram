# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Progr15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program for simple Interest

def simple_interest(p=0, r=0, t=0):
    return (p * r * t) / 100

#taking input from the user
p = float(input("Enter Principal: "))
r = float(input("Enter Rate: "))
t = float(input("Enter Time: "))

print("Simple Interest:", simple_interest(p, r, t))
# Out:
# Enter Principal: 4000
# Enter Rate: 4
# Enter Time: 2
# Simple Interest: 320.0
