# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Program14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to check even or odd

#taking the input from the user
n = int(input("Enter N: "))

even_numbers = list(range(2, n+1, 2))
print(even_numbers)
