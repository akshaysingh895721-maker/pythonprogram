# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Program17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to check eligible for vote or Not Eligible

def check_vote(age):
    return "Eligible" if age >= 18 else "Not Eligible"

age = int(input("Enter age: "))
print(check_vote(age))
# Out:
# Enter age: 16
# Not Eligible
