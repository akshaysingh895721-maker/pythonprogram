# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Program22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to check Eligibility for Vote

#taking the input from the user
age = int(input("Enter age: "))

print("Eligible" if age >= 18 else "Not Eligible")
# Out:
# Enter age: 18
# Eligible
