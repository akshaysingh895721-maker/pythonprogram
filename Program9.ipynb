# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Program9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Program to find even number

#Taking the input from the user
n = int(input("Enter N: "))

i = 2
while i <= n:
    print(i, end=" ")
    i += 2
# Out:
# Enter N: 4
# 2 4
